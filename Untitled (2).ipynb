# %%
import pandas as pd
import math
import numpy as np
from sklearn.linear_model import LinearRegression
def myLinReg(x,y):
    df=pd.DataFrame({'x':x,'y':y})
    xmean=df['x'].mean()
    ymean=df['y'].mean()
    total=sum((df['x']-xmean)*(df['y']-ymean))
    xs=sum((df['x']-xmean)**2)
    b1=total/xs
    b0=ymean-b1*xmean
    return(b1,b0)
a,b= myLinReg([1,3,4,5,7],[6,14,10,14,26])
print(a,b)
# Out:
# 3.0 2.0

# %%
import numpy as np
mtcars=pd.read_csv("mtcars.csv")
x=np.array(mtcars["mpg"].values).reshape((-1, 1))
y=np.array(mtcars["wt"].values)
model = LinearRegression().fit(x, y)
r_sq = model.score(x, y)
b0=model.intercept_
b1=model.coef_
print('coefficient of determination:', r_sq)
print('b0:', b0)
print('b1:', b1)
y_pred = model.predict(x)
print('predicted response:', y_pred)
# Out:
# coefficient of determination: 0.7528327936582646
# b0: 6.047255013458306
# b1: [-0.14086197]
# predicted response: [3.08915365 3.08915365 2.8356021  3.03280886 3.41313618 3.49765336
#  4.03292884 2.61022295 2.8356021  3.34270519 3.53991195 3.73711871
#  3.61034293 3.90615307 4.58229053 4.58229053 3.97658406 1.48332719
#  1.76505113 1.27203423 3.01872266 3.86389448 3.90615307 4.17379081
#  3.34270519 2.20172324 2.3848438  1.76505113 3.82163589 3.27227421
#  3.93432547 3.03280886]

# %%
def myLinReg(a,b):
    x=np.array(a).reshape((-1, 1))
    y=np.array(b)
    model = LinearRegression().fit(x, y)
   # r_sq = model.score(x, y)
    b0=model.intercept_
    b1=model.coef_
    return(b1,b0)
a,b=myLinReg([1,3,4,5,7],[6,14,10,14,26])
print(a,b)
# Out:
# [3.] 2.0000000000000036

# %%
a,b=myLinReg(mtcars["mpg"].values,mtcars["wt"].values)
print(a,b)
# Out:
# [-0.14086197] 6.047255013458306

# %%
float(a*5.5+b)
# Out:
# 5.272514179162674

# %%
boston=pd.read_csv("Boston.csv")
boston.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
x=boston.iloc[:,1:14]
y=boston.iloc[:,-1]
y=np.round(boston['medv'])
bestfeatures=SelectKBest(score_func=chi2,k=5)
fit=bestfeatures.fit(x,y)
dfscores=pd.DataFrame(fit.scores_)
dfcolumns=pd.DataFrame(x.columns)
featurescores=pd.concat([dfcolumns,dfscores],axis=1)
featurescores.columns=['specs','scores']
print(featurescores.nlargest(5,'scores'))
# Out:
#     specs        scores
# 9     tax  14817.836927
# 1      zn   5937.859414
# 0    crim   5503.817133
# 11  black   3340.486412
# 6     age   2424.308937

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=0)
model=LinearRegression().fit(x_train,y_train)
yp=model.predict(x_train)
yp
# Out:
# array([32.54992525, 21.8760586 , 27.49052323, 23.6135203 ,  6.50906485,
#        15.01197765, 22.20670643, 29.10461975, 33.25958246, 13.0612058 ,
#        20.24068197, 20.68690583, 12.58618789, 23.3171207 ,  5.04032179,
#        19.80673036,  9.37711811, 44.49992791, 30.76485194, 12.48536697,
#        17.67335462, 21.40551666, 23.62809021, 20.30465405, 34.95001875,
#        13.79305681, 21.03212021, 35.07413069, 19.43629785, 13.19160788,
#        14.0362019 , 23.096657  , 14.43206429, 31.13854548, 25.30617554,
#        15.45530028, 24.21782155,  9.38273506, 14.84485769, 20.82897312,
#        32.74701308, 27.95901328, 25.5684571 , 15.56636771, 31.01161617,
#        28.01460751, 14.03507429,  7.54048211, 28.46541765, 25.38477941,
#         4.36433229, 28.32283274, 17.13229915, 29.6814786 , 20.32345421,
#        15.89015955, 17.83760878, 12.68615583,  8.7919297 , 19.22899108,
#        34.48710692, 32.97743353, 23.70548415, 19.54975924, 22.8466262 ,
# ...

# %%
from sklearn.metrics import r2_score
print('Model accuracy :',r2_score(y,model.predict(x))*100)
# Out:
# Model accuracy : 73.63985495216482
